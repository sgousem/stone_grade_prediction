# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# %matplotlib inline
import cv2

# %%
x= [x for x in range(1,11)]
y = [x*2 for x in range(1,11)]
img = cv2.imread('mm.jpg')
fig, ax = plt.subplots(1)
ax.imshow(img)
#ax.text(5, 5, 'your legend', bbox={'facecolor': 'white', 'pad': 10})
plt.text(0.5, 0.5,'matplotlib', ha='center', va='center', transform=ax.transAxes,fontsize=25,bbox=dict(facecolor='yellow', alpha=0.5))
#graph.set_xlabel = 'normal'
#graph.set_ylabel = 'square'
#graph.set_title = 'simple graph'
#plt.show()
# Out:
# Text(0.5, 0.5, 'matplotlib')
